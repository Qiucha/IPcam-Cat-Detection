# %%
import cv2
import requests

# For Android IP Webcam
# import numpy as np
# from requests.auth import HTTPBasicAuth

from dotenv import load_dotenv
import os
load_dotenv()

from ultralytics import YOLO

from threading import Timer
import time
import datetime

import base64

user = os.getenv('USER')
password = os.getenv('PASSWORD')
url = os.getenv('URL')

ntfy_user=os.getenv('NTFY_USER')
ntfy_pass=os.getenv('NTFY_PASS')

proj_path = os.getenv('PROJ_PATH')

host = os.getenv('HOSTNAME')
topic = os.getenv('TOPIC')

model = YOLO(os.getenv('MODEL'))

suspend = os.getenv('SUSPEND')

os.environ["OPENCV_FFMPEG_CAPTURE_OPTIONS"] = "rtsp_transport;0"

# %%
def get_img_from_ipcam_stream(
    url:str = None,
    user:str = None,
    password:str = None
    ):
  
  if url is None:
    raise ValueError("url is Empty")
  if user is None or password is None:
    raise Warning("Username and password not set, check if your server is set to with password.")
  
  # ipcam = cv2.VideoCapture(url, cv2.CAP_FFMPEG)
  # ret, frame = ipcam.read()
  # if ret:
  #   img = cv2.imdecode(frame, cv2.IMREAD_COLOR)

  # For Android IP webcam
  img_resp = requests.get(url, auth=HTTPBasicAuth(username=user, password=password))
  img_arr = np.array(bytearray(img_resp.content), dtype=np.uint8) 
  img = cv2.imdecode(img_arr, cv2.IMREAD_COLOR)
  
  return img

# %%
def extract_model_prediction(model, img) -> dict:
  result = model(img)[0]
  max_conf = 0
  for conf, cs in zip(result.boxes.conf, result.boxes.cls):
    if conf >= 0.3 and result.names[int(cs)] == 'cat' and (conf >= max_conf):
      max_conf = conf
  
  msg_dict = None
  if max_conf >= 0.8:
    msg_dict = {
      "pr": "default",
      "title": "Cat Detected!",
      "msg": f"Found cat at confedence level: {conf}",
      # "img": img,
      "tags": "tada"
    }
  elif max_conf >= 0.3:
    msg_dict = {
      "pr": "low",
      "title": "Cat Detected! Probably...",
      "msg": f"Found cat at confedence level: {conf}. This could be wrong.",
      # "img": img,
      "tags": "tada"
    }
  else:
    msg_dict = None

  return msg_dict

# %%
def push_ntfy(
    host:str = None,
    topic:str = None,
    msg_dict:dict= None,
    img_path = None
    ):
  auth = base64.b64encode((ntfy_user+":"+ntfy_pass).encode('UTF-8'))

  requests.post(
    f"https://{host}/{topic}",               
    data=msg_dict['msg'].encode(encoding='utf-8'),
    headers={
      "Authorization": auth,
      "Title": msg_dict['title'],
      "Priority": msg_dict['pr'],
      "Tags": msg_dict['tags']
    }
  )

  if img_path is not None:
    data = open(img_path, "rb")
    filename = img_path.split('/')[-1]
    requests.put(
      f"https://{host}/{topic}",
      data=data,
      headers={"Filename": filename}
    )

# %%
def chk_crt_path(path):
  if not os.path.exists(path):
    os.mkdir(path)
  elif not os.path.isdir(path):
    raise ValueError("path given exists and is not a directory.")

# %%
import cv2
import threading

class RTSPStream:
  def __init__(self, rtsp_url):
    self.rtsp_url = rtsp_url
    self.cap = cv2.VideoCapture(self.rtsp_url, cv2.CAP_FFMPEG)
    self.frame = None
    self.lock = threading.Lock()
    self.running = True
    threading.Thread(target=self.update, daemon=True).start()

  def update(self):
    while self.running:
      ret, frame = self.cap.read()
      if ret:
        with self.lock:
          self.frame = frame

  def get_frame(self):
    with self.lock:
      return self.frame.copy() if self.frame is not None else None

  def stop(self):
    self.running = False
    self.cap.release()

# %%
# Initialize threaded RTSP stream
stream = RTSPStream(url)

threshold = 500
activation = 0
step = 20

chk_crt_path(f"{proj_path}/saved_img")

while True:
  try:
    frame = stream.get_frame()
    filename=f"{proj_path}/saved_img/{datetime.datetime.now().strftime('%c')}.jpg"
    
    if frame is not None:
      msg_dict = extract_model_prediction(model, frame)
      
      if msg_dict is not None:
        activation += step
      else:
        activation -= (step/10)

      if activation >= threshold:
        cv2.imwrite(filename, frame)
        push_ntfy(host, topic, msg_dict, filename)

        time.sleep(SUSPEND)
        activation = 0
      
  except KeyboardInterrupt:
    break

stream.stop()
# Out:
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 42 0
# [h264 @ 0x15085a140] out of range intra chroma pred mode
# [h264 @ 0x15085a140] error while decoding MB 14 2
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 48 0
# [h264 @ 0x15085a140] mb_type 34 in P slice too large at 74 0
# [h264 @ 0x15085a140] error while decoding MB 74 0
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 44 0
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 61 0
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 49 0
# [h264 @ 0x15085a140] cbp too large (61) at 47 0
# [h264 @ 0x15085a140] error while decoding MB 47 0
# [h264 @ 0x15085a140] negative number of zero coeffs at 6 3
# [h264 @ 0x15085a140] error while decoding MB 6 3
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 44 0
# [h264 @ 0x15085a140] out of range intra chroma pred mode
# [h264 @ 0x15085a140] error while decoding MB 53 1
# [h264 @ 0x15085a140] cbp too large (54) at 41 0
# [h264 @ 0x15085a140] error while decoding MB 41 0
# [h264 @ 0x15085a140] top block unavailable for requested intra mode
# [h264 @ 0x15085a140] error while decoding MB 42 0
# frame is not empty!
# [h264 @ 0x15059ca40] top block unavailable for requested intra mode
# [h264 @ 0x15059ca40] error while decoding MB 42 0
# [h264 @ 0x15059a3c0] out of range intra chroma pred mode
# [h264 @ 0x15059a3c0] error while decoding MB 14 2
# [h264 @ 0x1505c3db0] top block unavailable for requested intra mode
# [h264 @ 0x1505c3db0] error while decoding MB 48 0
# [h264 @ 0x1505cc610] mb_type 34 in P slice too large at 74 0
# [h264 @ 0x1505cc610] error while decoding MB 74 0
# [h264 @ 0x1505d4e70] top block unavailable for requested intra mode
# [h264 @ 0x1505d4e70] error while decoding MB 44 0
# [h264 @ 0x1505dd6d0] top block unavailable for requested intra mode
# [h264 @ 0x1505dd6d0] error while decoding MB 61 0
# [h264 @ 0x1505e5f30] top block unavailable for requested intra mode
# [h264 @ 0x1505e5f30] error while decoding MB 49 0
# [h264 @ 0x1505ee790] cbp too large (61) at 47 0
# [h264 @ 0x1505ee790] error while decoding MB 47 0
# [h264 @ 0x15059ca40] negative number of zero coeffs at 6 3
# [h264 @ 0x15059ca40] error while decoding MB 6 3
# [h264 @ 0x15059a3c0] top block unavailable for requested intra mode
# [h264 @ 0x15059a3c0] error while decoding MB 44 0
# [h264 @ 0x1505c3db0] out of range intra chroma pred mode
# [h264 @ 0x1505c3db0] error while decoding MB 53 1
# [h264 @ 0x1505cc610] cbp too large (54) at 41 0
# [h264 @ 0x1505cc610] error while decoding MB 41 0
# [h264 @ 0x1505d4e70] top block unavailable for requested intra mode
# [h264 @ 0x1505d4e70] error while decoding MB 42 0
# 0: 384x640 (no detections), 67.4ms
# Speed: 3.5ms preprocess, 67.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.3ms
# Speed: 0.7ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.7ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.8ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 0.9ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.7ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 0.8ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 46.7ms
# Speed: 0.8ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 0.7ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.6ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 79.2ms
# Speed: 0.8ms preprocess, 79.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
# [h264 @ 0x15059ca40] corrupted macroblock 8 3 (total_coeff=-1)
# [h264 @ 0x15059ca40] error while decoding MB 8 3
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.7ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 0.7ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 0.8ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 0.7ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.8ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 0.7ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.8ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.6ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 0.8ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 0.8ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.7ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.9ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 0.7ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.8ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 0.7ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.7ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.9ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 0.8ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 0.8ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.8ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 0.7ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 0.8ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 1.2ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.8ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.7ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
# [rtsp @ 0x10a3181b0] Too short data for FU-A H.264 RTP packet
# 0: 384x640 (no detections), 47.2ms
# Speed: 0.9ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.6ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.9ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.7ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.8ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 0.7ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 0.8ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 0.7ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.7ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.7ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 70.9ms
# Speed: 0.9ms preprocess, 70.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 0.7ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 0.7ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.8ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.6ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 0.7ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 0.8ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 0.8ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 0.7ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 0.7ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 0.9ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 0.9ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 0.8ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.7ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.2ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 0.8ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.2ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 0.8ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 57.6ms
# Speed: 0.9ms preprocess, 57.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 84.1ms
# Speed: 1.1ms preprocess, 84.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 89.0ms
# Speed: 3.6ms preprocess, 89.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.2ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.1ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 98.5ms
# Speed: 1.2ms preprocess, 98.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 0.8ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 0.8ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 0.7ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.9ms
# Speed: 0.8ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.1ms
# Speed: 1.0ms preprocess, 36.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.3ms
# Speed: 0.7ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 0.8ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 0.6ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.2ms
# Speed: 0.7ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 35.7ms
# Speed: 0.7ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 47.0ms
# Speed: 0.9ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.1ms
# Speed: 0.9ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.0ms
# Speed: 0.8ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 0.7ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 1.3ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 1.5ms preprocess, 57.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.2ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 0.8ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 106.2ms
# Speed: 1.2ms preprocess, 106.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 0.7ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.7ms
# Speed: 0.9ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 0.8ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 0.7ms preprocess, 55.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 60.2ms
# Speed: 1.4ms preprocess, 60.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 1.2ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.5ms
# Speed: 0.8ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.9ms
# Speed: 0.8ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 0.8ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 0.7ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 0.7ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 0.9ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 89.0ms
# Speed: 1.4ms preprocess, 89.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 86.6ms
# Speed: 1.1ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 (no detections), 50.5ms
# ...
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.7ms
# Speed: 0.9ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 39.5ms
# Speed: 0.7ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 39.8ms
# Speed: 0.9ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.4ms
# Speed: 0.6ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 42.6ms
# Speed: 0.7ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.3ms
# Speed: 0.6ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.9ms
# Speed: 0.8ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 40.7ms
# Speed: 0.7ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 38.5ms
# Speed: 0.7ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 39.8ms
# Speed: 0.7ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.5ms
# Speed: 0.7ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 1 tv, 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.2ms
# Speed: 0.9ms preprocess, 39.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 41.4ms
# Speed: 0.6ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 41.5ms
# Speed: 1.0ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.3ms
# Speed: 0.7ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.2ms
# Speed: 0.8ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.8ms
# Speed: 0.7ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.6ms
# Speed: 0.6ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 40.2ms
# Speed: 0.8ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 39.3ms
# Speed: 0.7ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.5ms
# Speed: 0.9ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.2ms
# Speed: 1.0ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 41.5ms
# Speed: 0.7ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 55.0ms
# Speed: 0.7ms preprocess, 55.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 38.2ms
# Speed: 0.7ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 37.8ms
# Speed: 0.7ms preprocess, 37.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.8ms
# Speed: 0.7ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.4ms
# Speed: 0.6ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 68.8ms
# Speed: 0.9ms preprocess, 68.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.9ms
# Speed: 0.7ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 40.0ms
# Speed: 0.8ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 44.4ms
# Speed: 0.7ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# Activated
# [h264 @ 0x1505ee790] negative number of zero coeffs at 33 6
# [h264 @ 0x1505ee790] error while decoding MB 33 6
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 131.3ms
# Speed: 34.4ms preprocess, 131.3ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 2 cats, 1 bowl, 55.8ms
# Speed: 0.7ms preprocess, 55.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 55.7ms
# Speed: 1.5ms preprocess, 55.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 54.1ms
# Speed: 1.8ms preprocess, 54.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 59.4ms
# Speed: 1.6ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 60.0ms
# Speed: 0.7ms preprocess, 60.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 person, 1 cat, 1 bowl, 47.6ms
# Speed: 0.8ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 48.2ms
# Speed: 1.2ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 46.2ms
# Speed: 0.8ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 46.1ms
# Speed: 0.9ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 47.4ms
# Speed: 0.7ms preprocess, 47.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 53.7ms
# Speed: 0.9ms preprocess, 53.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 99.6ms
# Speed: 0.9ms preprocess, 99.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# frame is not empty!
#
# 0: 384x640 1 cat, 1 bowl, 56.5ms
# Speed: 0.7ms preprocess, 56.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# msg_dict is not empty!
# Activated
# [h264 @ 0x15059ca40] cbp too large (3199971767) at 29 11
# [h264 @ 0x15059ca40] error while decoding MB 29 11
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
test_img = proj_path + '/test_img/test1.jpg'

file= f"{proj_path}/saved_img/{datetime.datetime.now().strftime('%c')}.jpg"

img = cv2.imread(test_img)
cv2.imwrite(file, img)

if img is None:
  raise ValueError("Image doesn't exist.")
else:
  model = YOLO('yolov8n.pt')
  msg_dict = extract_model_prediction(model, img)
  if msg_dict is not None:
    push_ntfy(host, topic, msg_dict, file)
